# %% [markdown]
# # demo: answer questions based on the information in a PDF file

# %%
import pandas as pd
import sys

import os
sys.path.insert(0, r'C:\Repositories others\LLM-data-processer')

from llm_helper import read_pdf2text, AIHelper
ai = AIHelper()
# Out:
# Initialized AIHelper with model: Mistral-7B

# %% [markdown]
# # Demo 1: reading PDF file (simple)

# %%
# Read PDF file
pdf_text = read_pdf2text('./data/CarnotBattery_Wikipedia.pdf')

# Attach the PDF content to AI
ai.attach_data('pdf document', pdf_text)
# Out:
# Data added: pdf document; data type: <class 'str'>; data size: 14797 characters

# %%
ai.ask('what is the efficiency of Carnot battery according to the document?')

# %%
ai.ask('in previous question, answer in the formation of "Efficiency: ...%": source: ...; ... and so on')
